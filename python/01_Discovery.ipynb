# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/VirtualFlyBrain/neurofly2026-workshop/blob/main/python/01_Discovery.ipynb)

# %% [markdown]
# # 01 · Discovery — finding neurons across datasets
# **Problem P1:** *Find every instance of a neuron type across all datasets.*
#
# VFB classifies neurons from every source with one ontology ([Drosophila Anatomy Ontology](https://www.ebi.ac.uk/ols4/ontologies/fbbt)), so a single query for a *type* returns individuals from FlyWire, hemibrain, BANC, male-CNS, MANC, optic-lobe and CATMAID at once — no wrangling nomenclature.

# %% [markdown]
# **First time in Colab?** Click the **▶ (play) icon** on the left edge of the code cell below to run it (or press `Shift+Enter`).
#
# You'll likely see a warning like:
#
# ```
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ```
#
# That's expected — Colab's own pre-installed packages briefly clash with one this notebook installs. It doesn't affect anything below; safe to ignore.

# %%
# Run once per Colab session (skip if already installed locally).
# %pip install -q vfb_connect navis flybrains neuprint-python python-catmaid plotly
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 75.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 84.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 MB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.7/191.7 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 99.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 109.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 24.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.5/326.5 kB 24.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.7/287.7 kB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.1/245.1 kB 20.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.0/750.0 kB 47.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.5/464.5 kB 33.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.4 MB/s eta 0:00:00
#   Building wheel for asciitree (setup.py) ... done
#   Building wheel for pysolr (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
from vfb_connect import vfb   # first import connects to VFB services (~2 min, then fast)
import pandas as pd
# Out:
# Welcome to the Virtual Fly Brain API
# See the documentation at: https://virtualflybrain.org/docs/tutorials/apis/
#
# Establishing connections to https://VirtualFlyBrain.org services...
# Session Established!
#
# Type vfb. and press tab to see available queries. You can run help against any query e.g. help(vfb.terms)

# %% [markdown]
# ## Route A — `vfb_connect`
# Find the type name/symbol first via the [VFB search](https://virtualflybrain.org), then pull its instances. Substitute a type *you* care about.

# %% [markdown]
# **Worked example:** the DA1 lateral projection neuron (`DA1 lPN`, `FBbt_00067363`) — a well-studied olfactory PN. In VFB it resolves to **68 individuals** spanning hemibrain, FlyWire, BANC, male-CNS and FAFB. (It's *absent* from MANC and the optic lobe — it's a central-brain neuron, not in the nerve cord or optic lobe — a good reminder that not every cell is in every dataset.)

# %%
# All individual neurons of a given type, across every dataset.
neuron_type = 'adult antennal lobe projection neuron DA1 lPN'   # DA1 lPN — change me
df = vfb.get_instances(neuron_type)   # returns a DataFrame
df.head(10)
# Out:
#                                           label     symbol            id  \
# 0                     DA1_lPN_L (MaleCNS:13583)             VFB_jrmc37h3
# 1                     DA1_lPN_R (MaleCNS:13064)             VFB_jrmc37h9
# 2               DA1_lPN_R (FlyEM-HB:1765040289)  DA1_lPN_R  VFB_jrchjtdc
# 3     AL.MB_CA.133 (FlyWire:720575940617229632)    DA1_lPN  VFB_fw013615
# 4                   BANC_888:720575941432492247             VFB_00106auk
# 5      AL.MB_CA.83 (FlyWire:720575940630066007)    DA1_lPN  VFB_fw035286
# 6                     DA1_lPN_L (MaleCNS:12314)             VFB_jrmc37ha
# 7  Uniglomerular mALT DA1 lPN#L1 (FAFB:4207871)             VFB_0010126e
# 8  Uniglomerular mALT DA1 lPN#L6 (FAFB:2381753)             VFB_0010123b
# 9                     DA1_lPN_L (MaleCNS:11721)             VFB_jrmc37h0
#
#                                                 tags data_source  \
# 0  [Entity, Individual, VFB, Neuron, Adult, Anato...        [mc]
# 1  [Entity, Individual, VFB, Neuron, Adult, Anato...        [mc]
# 2  [Entity, Individual, VFB, Neuron, Adult, Anato...        [hb]
# 3  [Entity, Individual, VFB, Neuron, Adult, Anato...        [fw]
# 4  [Entity, Individual, VFB, Neuron, Adult, Anato...      [BANC]
# 5  [Entity, Individual, VFB, Neuron, Adult, Anato...        [fw]
# 6  [Entity, Individual, VFB, Neuron, Adult, Anato...        [mc]
# 7  [Entity, Individual, VFB, Neuron, Adult, Anato...      [fafb]
# 8  [Entity, Individual, VFB, Neuron, Adult, Anato...      [fafb]
# 9  [Entity, Individual, VFB, Neuron, Adult, Anato...        [mc]
#
#               accession                                      parents_label  \
# 0               [13583]    [adult antennal lobe projection neuron DA1 lPN]
# 1               [13064]    [adult antennal lobe projection neuron DA1 lPN]
# 2          [1765040289]  [adult fruitless aDT-e (female) neuron, adult ...
# 3  [720575940617229632]  [adult fruitless aDT-e (female) neuron, adult ...
# 4  [720575941432492247]  [adult antennal lobe projection neuron DA1 lPN...
# 5  [720575940630066007]  [adult fruitless aDT-e (female) neuron, adult ...
# 6               [12314]    [adult antennal lobe projection neuron DA1 lPN]
# 7             [4207871]  [adult antennal lobe projection neuron DA1 lPN...
# 8             [2381753]  [adult fruitless aDT-e (female) neuron, adult ...
# 9               [11721]    [adult antennal lobe projection neuron DA1 lPN]
#
#                        parents_id  \
# 0                 [FBbt_00067363]
# 1                 [FBbt_00067363]
# 2  [FBbt_00110423, FBbt_00067363]
# 3  [FBbt_00110423, FBbt_00067363]
# 4  [FBbt_00067363, FBbt_00110423]
# 5  [FBbt_00110423, FBbt_00067363]
# 6                 [FBbt_00067363]
# 7  [FBbt_00067363, FBbt_00110423]
# 8  [FBbt_00110423, FBbt_00067363]
# 9                 [FBbt_00067363]
#
#                                                xrefs  \
# 0                    [male_cns_v0_9:13583, mc:13583]
# 1                    [male_cns_v0_9:13064, mc:13064]
# 2  [hb:1765040289, neuronbridge:hemibrain:1765040...
# 3  [fw:720575940617229632, neuronbridge:flywire_f...
# 4  [BANC:720575941432492247, BANC626:720575941432...
# 5  [neuronbridge:flywire_fafb:720575940630066007,...
# 6                    [mc:12314, male_cns_v0_9:12314]
# 7                                     [fafb:4207871]
# 8                                     [fafb:2381753]
# 9                    [mc:11721, male_cns_v0_9:11721]
#
#                               templates                               dataset  \
# 0                       [JRC2018Unisex]                 [Berg2025a, Berg2025]
# 1     [JRC2018UnisexVNC, JRC2018Unisex]                 [Berg2025a, Berg2025]
# 2  [JRC2018Unisex, JRC_FlyEM_Hemibrain]         [Xu2020NeuronsV1point2point1]
# 3                       [JRC2018Unisex]                      [Dorkenwald2023]
# 4                       [JRC2018Unisex]                [Bates2026, Bates2025]
# 5                       [JRC2018Unisex]                      [Dorkenwald2023]
# 6     [JRC2018Unisex, JRC2018UnisexVNC]                 [Berg2025a, Berg2025]
# 7                       [JRC2018Unisex]  [BatesSchlegel2020, TaiszGalili2022]
# 8                       [JRC2018Unisex]  [BatesSchlegel2020, TaiszGalili2022]
# 9                       [JRC2018Unisex]                 [Berg2025, Berg2025a]
#
#                                              license
# 0  [https://creativecommons.org/licenses/by/4.0/l...
# 1  [https://creativecommons.org/licenses/by/4.0/l...
# 2  [https://creativecommons.org/licenses/by/4.0/l...
# 3  [https://creativecommons.org/licenses/by-nc/4....
# 4  [https://creativecommons.org/licenses/by/4.0/l...
# 5  [https://creativecommons.org/licenses/by-nc/4....
# 6  [https://creativecommons.org/licenses/by/4.0/l...
# 7  [https://creativecommons.org/licenses/by/4.0/l...
# 8  [https://creativecommons.org/licenses/by/4.0/l...
# 9  [https://creativecommons.org/licenses/by/4.0/l...

# %%
# Which datasets is this type represented in?
# Note: 'data_source' holds a *list* per row (a neuron can appear in more than one
# source), so explode it before counting.
col = 'data_source' if 'data_source' in df.columns else 'dataset'
df[col].explode().value_counts()
# Out:
# data_source
# fw      15
# fafb    15
# mc      13
# hb       7
# BANC     7
# Name: count, dtype: int64

# %% [markdown]
# ### Find neurons by location
# The ontology also lets you ask 'what's *in* a region' — parts and overlapping cells.

# %%
region_terms = vfb.get_terms_by_region('fan-shaped body')  # try 'medulla', 'mushroom body'
pd.DataFrame(region_terms).head()
# Out:
#                                                label symbol             id  \
# 0  adult fan-shaped body-ellipsoid body-nodulus n...         FBbt_00003641
# 1                  adult fan-shaped body-bulb neuron         FBbt_00003642
# 2  adult protocerebral bridge-fan-shaped body 2 r...         FBbt_00003644
# 3  adult protocerebral bridge-fan-shaped body-ell...         FBbt_00003647
# 4         pupal protocerebral LPP2 Tachykinin neuron         FBbt_00110040
#
#                                                 tags  \
# 0  [Entity, Class, Neuron, Adult, Anatomy, Cell, ...
# 1  [Entity, Class, Neuron, Adult, Anatomy, Cell, ...
# 2  [Entity, Class, Neuron, Adult, Anatomy, Cell, ...
# 3  [Entity, Class, Neuron, Adult, Anatomy, Cell, ...
# 4  [Entity, Class, Neuron, Adult, Anatomy, Cell, ...
#
#                                          description  \
# 0  A small field neuron intrinsic to the central ...
# 1  A small field neuron of the adult central comp...
# 2  A small field neuron of the adult central comp...
# 3  A small field neuron of the adult central comp...
# 4  Pupal neuron that expresses Tachykinin (FBgn00...
#
#                                        parents_label  \
# 0  [intrinsic neuron of the central complex, smal...
# 1        [small field neuron of the central complex]
# 2  [adult protocerebral bridge-fan-shaped body ne...
# 3  [intrinsic neuron of the central complex, smal...
# 4  [pupal Tachykinin neuron of the central nervou...
#
#                                           parents_id data_source accession  \
# 0                     [FBbt_00053387, FBbt_00007514]          []        []
# 1                                    [FBbt_00007514]          []        []
# 2                                    [FBbt_00111050]          []        []
# 3                     [FBbt_00053387, FBbt_00007514]          []        []
# 4  [FBbt_00110062, FBbt_00058202, FBbt_00059274, ...          []        []
#
#                   xrefs
# 0                    []
# 1  [FlyBrain_NDB:10258]
# 2                    []
# 3  [FlyBrain_NDB:10243]
# 4                    []

# %% [markdown]
# ### What's *new* since 2024?
# The 2026-era connectomes already show up in the instance table above. Filter to the neurons that come from datasets added since the last workshop (BANC whole-CNS, male-CNS):

# %%
# Which of these individuals come from datasets that did not exist at the 2024 workshop?
# 'data_source' is a list column, so test set-membership rather than string matching.
new_since_2024 = {'BANC', 'mc', 'ol'}   # whole-CNS, male-CNS, optic lobe
mask = df['data_source'].apply(lambda s: bool(new_since_2024 & set(s)))
new_sets = df[mask]
print(f'{len(new_sets)} of {len(df)} DA1 lPN individuals are in datasets new since 2024')
new_sets[['label', 'id', 'data_source']].head(10)
# Out:
# 20 of 57 DA1 lPN individuals are in datasets new since 2024
#                           label            id data_source
# 0     DA1_lPN_L (MaleCNS:13583)  VFB_jrmc37h3        [mc]
# 1     DA1_lPN_R (MaleCNS:13064)  VFB_jrmc37h9        [mc]
# 4   BANC_888:720575941432492247  VFB_00106auk      [BANC]
# 6     DA1_lPN_L (MaleCNS:12314)  VFB_jrmc37ha        [mc]
# 9     DA1_lPN_L (MaleCNS:11721)  VFB_jrmc37h0        [mc]
# 11  BANC_888:720575941540123740  VFB_00105ld7      [BANC]
# 16  BANC_888:720575941479047648  VFB_001065vp      [BANC]
# 20    DA1_lPN_R (MaleCNS:11780)  VFB_jrmc37h8        [mc]
# 21    DA1_lPN_R (MaleCNS:11996)  VFB_jrmc37h5        [mc]
# 26  BANC_888:720575941491218608  VFB_001061t4      [BANC]

# %% [markdown]
# ---
# *This notebook is the Python route only. The MCP, chat, 3D-browser and R routes for this problem live on the [workshop page](https://workshop.virtualflybrain.org/sessions/session-1-discovery/).*

# %% [markdown]
# ### 🧪 Your turn
# Pick a neuron type from your own work. How many datasets is it in? Does **BANC** or **male-CNS** add instances that weren't available in 2024?
